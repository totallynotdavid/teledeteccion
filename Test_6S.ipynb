# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/py6s-env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from Py6S import SixS, SixSHelpers, Wavelength, AeroProfile
s = SixS()
s.wavelength = Wavelength(0.675)
s.aero_profile = AeroProfile.PredefinedType(AeroProfile.Maritime)
s.run()
print, s.outputs.pixel_reflectance, s.outputs.pixel_radiance, s.outputs.direct_solar_irradiance
wavelengths, results = SixSHelpers.Wavelengths.run_vnir(s, output_name='pixel_radiance')
SixSHelpers.Wavelengths.plot_wavelengths(wavelengths, results, "Pixel radiance ($W/m^2$)")
# Out:
# Running for many wavelengths - this may take a long time
